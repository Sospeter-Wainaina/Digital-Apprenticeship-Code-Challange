# %%
import pandas as pd
import numpy as np
from urllib.request import urlretrieve

# %%
#Putting it all together
def url_checker(url):
    #download data to local machine
    urlretrieve(url, "water_points.json")
    #read the json file
    #####TASK 1########
    df = pd.read_json("water_points.json")
    #variable to store no. of functional waterpoints
    func_waterpoints = int(df['water_functioning'].value_counts()[0])
    #creating the dictionary
    func_waterpoints_dict = {"number_functional":func_waterpoints}
    #####TASK 2#########
    #total waterpoints per community is: 
    frame = df["communities_villages"].value_counts().to_dict()
    #naming dictionary appropriately
    #####TASK 3########
    #e rank for each community by the percentage of broken water points.
    broken_dict = df.groupby("communities_villages")["water_functioning"].value_counts().unstack()["no"].fillna(0).to_dict()
    #creating a dict which will perform %of broken waterpoints not functioning
    rank_dict = {k: (broken_dict[k]/frame[k])*100 for k in broken_dict.keys() and frame.keys()}
    #sorting dictionary
    sorted_values = sorted(rank_dict.values(),reverse=True)
    #create empty dictionary
    sorted_dict = {}
    #loop over the sorted values
    for i in sorted_values:
        for k in rank_dict.keys():
            if rank_dict[k] == i:
                sorted_dict[k] = rank_dict[k]
    #return a dictionary
    return {"number_functional":func_waterpoints_dict,
            "number_water_points":frame,
            "community_ranking":sorted_dict
    }
#calling our function
url_checker("https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json")
# Out:
# {'number_functional': {'number_functional': 623},
#  'number_water_points': {'Kpatarigu': 51,
#   'Jagsa': 38,
#   'Nayoku': 35,
#   'Guuta': 32,
#   'Nabulugu': 31,
#   'Zundem': 30,
#   'Zua': 28,
#   'Badomsa': 27,
#   'Bechinsa': 26,
#   'Kaasa': 25,
#   'Tantala': 22,
#   'Kubore': 18,
#   'Loagri_1_': 18,
#   'Zuedema': 18,
#   'Dorinsa': 17,
#   'Selinvoya': 13,
#   'Zangu-Vuga': 13,
#   'Arigu': 12,
#   'Kulbugu': 11,
#   'Guuta-Nasa': 11,
#   'Zanwara': 10,
#   'Banyangsa': 10,
#   'Kanwaasa': 9,
#   'Chansa': 9,
#   'Longsa': 9,
#   'Kurugu': 9,
#   'Luisa': 8,
#   'Kanbangsa': 8,
#   'Mwalorinsa': 8,
#   'Jaata': 8,
#   'Jiriwiensa': 8,
#   'Nyankpiensa': 8,
#   'Namgurima': 8,
#   'Jiningsa': 7,
#   'Soo': 7,
#   'Bandem': 7,
#   'Zukpeni': 6,
#   'Zogsa': 6,
#   'Nawaasa': 6,
#   'Tankangsa': 6,
#   'Kom': 6,
#   'Fiisa': 5,
#   'Vundema': 5,
#   'Piisa': 5,
#   'Gbaarigu': 5,
#   'Tuisa': 4,
#   'Logvasgsa': 4,
#   'Chondema': 4,
#   'Abanyeri': 4,
#   'Chanpolinsa': 4,
#   'Jiningsa-Yipaala': 3,
#   'Kpikpaluk': 3,
#   'Akpari-yeri': 3,
#   'Kunkwah': 3,
#   'Gbima': 3,
#   'Sikabsa': 3,
#   'Alavanyo': 3,
#   'Nyandema': 3,
#   'Gaadem': 2,
#   'Dibisi': 2,
#   'Garigu': 1,
#   'Suik': 1,
#   'Jiniensa': 1,
#   'Gumaryili': 1,
#   'Kalaasa': 1},
#  'community_ranking': {'Zukpeni': 66.66666666666666,
#   'Gbaarigu': 60.0,
#   'Arigu': 50.0,
#   'Namgurima': 50.0,
#   'Kurugu': 44.44444444444444,
#   'Bandem': 42.857142857142854,
#   'Zanwara': 40.0,
#   'Gbima': 33.33333333333333,
#   'Alavanyo': 33.33333333333333,
#   'Banyangsa': 30.0,
#   'Soo': 28.57142857142857,
#   'Kubore': 27.77777777777778,
#   'Tantala': 27.27272727272727,
#   'Chanpolinsa': 25.0,
#   'Loagri_1_': 22.22222222222222,
#   'Longsa': 22.22222222222222,
#   'Nayoku': 17.142857142857142,
#   'Zogsa': 16.666666666666664,
#   'Jagsa': 15.789473684210526,
#   'Zangu-Vuga': 15.384615384615385,
#   'Zua': 14.285714285714285,
#   'Nabulugu': 12.903225806451612,
#   'Kanwaasa': 11.11111111111111,
#   'Kpatarigu': 9.803921568627452,
#   'Kulbugu': 9.090909090909092,
#   'Selinvoya': 7.6923076923076925,
#   'Guuta': 6.25,
#   'Dorinsa': 5.88235294117647,
#   'Zundem': 0.0,
#   'Badomsa': 0.0,
#   'Bechinsa': 0.0,
#   'Kaasa': 0.0,
#   'Zuedema': 0.0,
#   'Guuta-Nasa': 0.0,
#   'Chansa': 0.0,
#   'Luisa': 0.0,
#   'Kanbangsa': 0.0,
#   'Mwalorinsa': 0.0,
#   'Jaata': 0.0,
#   'Jiriwiensa': 0.0,
#   'Nyankpiensa': 0.0,
#   'Jiningsa': 0.0,
#   'Nawaasa': 0.0,
#   'Tankangsa': 0.0,
#   'Kom': 0.0,
#   'Fiisa': 0.0,
#   'Vundema': 0.0,
#   'Piisa': 0.0,
#   'Tuisa': 0.0,
#   'Logvasgsa': 0.0,
#   'Chondema': 0.0,
#   'Abanyeri': 0.0,
#   'Jiningsa-Yipaala': 0.0,
#   'Kpikpaluk': 0.0,
#   'Akpari-yeri': 0.0,
#   'Kunkwah': 0.0,
#   'Sikabsa': 0.0,
#   'Nyandema': 0.0,
#   'Gaadem': 0.0,
#   'Dibisi': 0.0,
#   'Garigu': 0.0,
#   'Suik': 0.0,
#   'Jiniensa': 0.0,
#   'Gumaryili': 0.0,
#   'Kalaasa': 0.0}}
